# %%
#Libraries

import pandas as pd
import re 
import string

# Display the tweet fully using:
pd.set_option('display.max_colwidth', None)
pd.set_option('max_colwidth', None)

# %%
df = pd.read_csv('Matcha#Dataset.csv')
df2 = pd.read_csv('Matcha#DatasetTest.csv')

# %%
# to return columns' names of the dataset
df.columns
# Out:
# Index(['Created at', 'User', 'Tweet', 'ID', 'Number of Retweets',
#        'Number of likes', 'Source', 'Location'],
#       dtype='object')

# %%
# to return each column with the corresponding non-null values count and its data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3348 entries, 0 to 3347
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Created at          3348 non-null   object
#  1   User                3348 non-null   object
#  2   Tweet               3348 non-null   object
#  3   ID                  3348 non-null   float64
#  4   Number of Retweets  3348 non-null   int64
#  5   Number of likes     3348 non-null   int64
#  6   Source              3348 non-null   object
#  7   Location            2390 non-null   object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 209.4+ KB

# %%
# to return the count of non-null values in each column
df.count()
# Out:
# Created at            3348
# User                  3348
# Tweet                 3348
# ID                    3348
# Number of Retweets    3348
# Number of likes       3348
# Source                3348
# Location              2390
# dtype: int64

# %%
# to return the total number of rows
len(df)
# Out:
# 3348

# %%
# to return statistical calculations
df.describe()
# Out:
#                  ID  Number of Retweets  Number of likes
# count  3.348000e+03         3348.000000      3348.000000
# mean   1.577715e+18            0.250000         3.643967
# std    7.962897e+14            2.803906        40.340408
# min    1.576250e+18            0.000000         0.000000
# 25%    1.577080e+18            0.000000         0.000000
# 50%    1.577730e+18            0.000000         1.000000
# 75%    1.578390e+18            0.000000         2.000000
# max    1.579140e+18           77.000000      2132.000000

# %%
df.head()
# Out:
#                   Created at             User  \
# 0  2022-10-09 15:56:27+00:00  SPStavrosAuthor
# 1  2022-10-09 15:54:44+00:00     dellianarose
# 2  2022-10-09 15:36:25+00:00        DeeReads_
# 3  2022-10-09 14:57:00+00:00  atasteofmadness
# 4  2022-10-09 14:21:21+00:00        ogidigest
#
#                                                                                                                                                     Tweet  \
# 0                                      @LynnDiavol I try to drink matcha over coffee, because it helps with anxiety problems instead of making them worse
# 1  Height: 5’3”\nAge: 29\nShoe Size: 8 or 9 (depending on the shoe) \nZodiac Sign: Sagittarius \nTattoos: 1 \nPiercings: 2… https://t.co/VA5nQx4NuK
# 2                                                                                                                                    drink matcha and sin
# 3          Easy Vanilla Matcha Chai Latte recipe. This healthy warm comforting drink idea is vegan and gluten free, perfect on… https://t.co/CUpNVNNdbh
# 4                                                                                    did you drink your oatly matcha latte today? https://t.co/Hb9bu8SWGX
#
#              ID  Number of Retweets  Number of likes               Source  \
# 0  1.579140e+18                   0                0  Twitter for Android
# 1  1.579140e+18                   0                0   Twitter for iPhone
# 2  1.579130e+18                   0                1      Twitter Web App
# 3  1.579120e+18                   1                0      Twitter Web App
# 4  1.579110e+18                   0                0      Twitter Web App
#
#           Location
# 0           Canada
# 1  Ottawa, Ontario
# 2              NaN
# 3      Chicago, IL
# 4              NaN

# %%
df.shape
# Out:
# (3348, 8)

# %% [markdown]
# Data Issues:

# %%
# NORMALIZATION PROBLEM

# It's been noticed that some Twitter users use 'Matcha' and sometimes 'Macha' while referring to the same drink.
# Therefore, it will be normalized to 'Matcha' in all tweets.

#This method takes the tweet as the parameter, normalizes the drink's spelling, then returns it.
def normalize(tweet):
    text = re.sub("macha","matcha", tweet)
    return tweet

# %%
df['Tweet'] = df['Tweet'].apply(normalize)

# %%
#Return a sample of the dataset
df.sample(5)
# Out:
#                      Created at            User  \
# 3047  2022-10-04 01:14:12+00:00  Pandamokneeum2
# 531   2022-10-01 23:20:42+00:00        Neozhura
# 3092  2022-10-03 17:13:15+00:00     AUGUSTSWISH
# 2569  2022-10-07 08:00:02+00:00    matcha_sadou
# 1436  2022-10-05 09:46:56+00:00  Trishaaaaakaye
#
#                                                                                                                                                                     Tweet  \
# 3047                        @The3Yorkiteers @MrWuggums @KandHarpo @SirLongpaw @MrsSchabacker @cat_carmela @17castiel @CaptainChaos5 @_Demonia_… https://t.co/VIMt5zlFTf
# 531   Thank you for the tag @FennVT ! :)\n\nFood: Grilled fish 🐟\nDrink: Matcha latte 🍵\nColor: Teal 🔵🟢\nSeason: Spring 🌸\nAnim… https://t.co/Rh3PfdtcJf
# 3092                                           It’s matcha. I found it at the Asian market by chance. I bought the tools you use to make tea back when I visited Japan.
# 2569                      Zen exists in Japanese tea ceremony.\nThis is also related to the fact that SEN no Rikyu found a sense of beauty pec… https://t.co/Jitd7WhnXq
# 1436                                                                                                                                                 Matcha latte pls🥲
#
#                 ID  Number of Retweets  Number of likes  \
# 3047  1.577100e+18                   0                0
# 531   1.576350e+18                   1                3
# 3092  1.576980e+18                   0                0
# 2569  1.578290e+18                   2               12
# 1436  1.577600e+18                   0                0
#
#                        Source             Location
# 3047          Twitter Web App                  NaN
# 531           Twitter Web App          Forest lake
# 3092  Cheap Bots, Done Quick!        In your heart
# 2569          Twitter Web App  東京 千代田区
# 1436       Twitter for iPhone                    N

# %%
# To check if 'macha' has been replaced with 'matcha', an attempt to return any tweet that contains the word 'macha' is made
# However, the dataframe returned is empty, which means there aren't any tweets with the word 'macha', and our normalization
# is successful!

df[df['Tweet'].str.contains('macha')]
# Out:
#                      Created at             User  \
# 2105  2022-10-09 09:26:00+00:00     Kidding_Jeff
# 2106  2022-10-09 08:08:13+00:00     SheWhoIsMe01
# 2107  2022-10-09 02:37:40+00:00   EroticEeveeMFC
# 2109  2022-10-08 21:03:50+00:00      Bemcdon01Sr
# 2110  2022-10-08 20:04:54+00:00      ADHD_Cyborg
# 2111  2022-10-08 17:54:12+00:00        SpaceBard
# 2115  2022-10-07 23:45:02+00:00         Emby1781
# 2118  2022-10-06 13:38:10+00:00  KingNeptune1220
# 2127  2022-10-05 04:41:36+00:00         ivalicea
# 2131  2022-10-03 03:12:03+00:00         Gyrowoof
# 2137  2022-10-09 02:37:40+00:00   EroticEeveeMFC
# 2138  2022-10-08 17:54:12+00:00        SpaceBard
# 2139  2022-10-06 22:02:01+00:00  RocksZeeCatgirl
# 2140  2022-10-05 19:20:24+00:00      chrissycrip
# 2145  2022-10-03 05:09:42+00:00     RuskiRedneck
# 3327  2022-10-08 22:11:38+00:00        satourues
# 3329  2022-10-08 20:04:54+00:00      ADHD_Cyborg
# 3330  2022-10-08 15:53:34+00:00   IsmazatulHusna
# 3331  2022-10-08 07:30:07+00:00           fuigus
# 3334  2022-10-06 14:41:19+00:00         pixiebur
# 3335  2022-10-06 10:34:40+00:00         kirinece
# 3337  2022-10-05 19:20:24+00:00      chrissycrip
# 3340  2022-10-05 00:35:46+00:00    KimsyWhimsy79
# 3342  2022-10-03 11:59:36+00:00         moalollo
# 3346  2022-10-08 21:03:50+00:00      Bemcdon01Sr
# 3347  2022-10-06 20:45:38+00:00     amiris_brown
#
#                                                                                                                                                Tweet  \
# 2105                                                                     @peacefulplace I love macha,nearly equal green tea. https://t.co/4iLC3YApmx
# 2106  @LynnDiavol Try the Starbucks iced green (not macha) with Stevia. They shake it and it changes the viscosity a bit.… https://t.co/2cr6Pq2GNx
# 2107                                                                @JJ1XYZ It IS green tea! Not macha.\n\nMixed with raw honey &amp; oat milk &lt;3
# 2109                                                           @LynnDiavol I still drink coffee but I have macha green tea every day too.  Straight.
# 2110                                                @RiviereTosh @transientideas I love earl grey tea. You could also try green tea or a macha latte
# 2111  @LynnDiavol Green tea. I have bough macha once and that was good too. I didn't make it any special way. I did try i… https://t.co/kQtzcczFhX
# 2115  @SHB13426 I'll definitely have to try it out! I think they had some kind of grass tea or a macha tea, so I'll defin… https://t.co/JZgtniZLnp
# 2118                         @Twitch_Lobita I don’t even drink coffee… but if I go to star bucks I get the green macha tea😤 sooooo gooooooddd
# 2127                                                     @windupelezen lemon cake with a side of green macha tea! she quite loves that one! 😚💕
# 2131                                                                                    #Waff loves our #macha Green tea! XD https://t.co/fBEZQMBoLu
# 2137                                                                @JJ1XYZ It IS green tea! Not macha.\n\nMixed with raw honey &amp; oat milk &lt;3
# 2138  @LynnDiavol Green tea. I have bough macha once and that was good too. I didn't make it any special way. I did try i… https://t.co/kQtzcczFhX
# 2139                                                                       @ManicMoths Iced macha, whole milk, and strawberry compote and honey boba
# 2140                                                                                   currently iced macha latte w oat milk https://t.co/AJ1EMOUeAr
# 2145  Coffe macha carmel late with chocolate milk because they didn't have regular milk in the vending machine tast not g… https://t.co/DBaDORam2Y
# 3327                                                                                         i blame that macha latte i drank at 9pm last night 💀
# 3329                                                @RiviereTosh @transientideas I love earl grey tea. You could also try green tea or a macha latte
# 3330                 @polychompo Baru buka Julai haritu. Try their macha latte if you go there okie. Their pastries, buns &amp; cakes also nice 😄
# 3331                                                           Trying out the orange yoghurt cheesecake and the macha latte. https://t.co/xKCLL5xyuH
# 3334                                                                                                                      guys What is a macha latte
# 3335          Guess who arriveddd fucking keito with his stupid face and the choco macha latte @addictwithawine sent me 💕 https://t.co/P9NOaPMOvo
# 3337                                                                                   currently iced macha latte w oat milk https://t.co/AJ1EMOUeAr
# 3340                                            @johnfeal2 @Jim_Jordan My $500 soy macha papa topya gobbledegook latte was great! Worth every penny!
# 3342                                                                  I just ordered macha latte and i got a fucking artwork https://t.co/tV6Dls3WEx
# 3346                                                           @LynnDiavol I still drink coffee but I have macha green tea every day too.  Straight.
# 3347                                                                                          @josephdelong @DeanEigenmann I go and drink macha 🍵
#
#                 ID  Number of Retweets  Number of likes               Source  \
# 2105  1.579040e+18                   0                0   Twitter for iPhone
# 2106  1.579020e+18                   0                0     Twitter for iPad
# 2107  1.578940e+18                   0                0      Twitter Web App
# 2109  1.578850e+18                   0                0      Twitter Web App
# 2110  1.578840e+18                   0                2  Twitter for Android
# 2111  1.578810e+18                   0                0      Twitter Web App
# 2115  1.578530e+18                   0                1  Twitter for Android
# 2118  1.578020e+18                   0                0   Twitter for iPhone
# 2127  1.577520e+18                   0                1      Twitter Web App
# 2131  1.576770e+18                   0                0  Twitter for Android
# 2137  1.578940e+18                   0                0      Twitter Web App
# 2138  1.578810e+18                   0                1      Twitter Web App
# 2139  1.578140e+18                   0                0  Twitter for Android
# 2140  1.577740e+18                   0                0   Twitter for iPhone
# 2145  1.576800e+18                   0                0  Twitter for Android
# 3327  1.578870e+18                   0                0   Twitter for iPhone
# 3329  1.578840e+18                   0                2  Twitter for Android
# 3330  1.578780e+18                   0                0   Twitter for iPhone
# 3331  1.578650e+18                   0                0   Twitter for iPhone
# 3334  1.578030e+18                   0                1  Twitter for Android
# 3335  1.577970e+18                   1               10  Twitter for Android
# 3337  1.577740e+18                   0                0   Twitter for iPhone
# 3340  1.577460e+18                   0                4   Twitter for iPhone
# 3342  1.576900e+18                   0                2  Twitter for Android
# 3346  1.578850e+18                   0                0      Twitter Web App
# 3347  1.578120e+18                   0                1  Twitter for Android
#
#                             Location
# 2105                           JAPAN
# 2106                             NaN
# 2107                     Los Angeles
# 2109                             NaN
# 2110                             NaN
# 2111                         Chicago
# 2115                             NaN
# 2118                             NaN
# 2127                     Radz-at-Han
# 2131                  Little red dot
# 2137                     Los Angeles
# 2138                         Chicago
# 2139                             NaN
# 2140
# 2145                    Glenview, IL
# 3327  i: @Akila29582577 h: @a_iupfor
# 3329                             NaN
# 3330         Putrajaya ↔️ Ampang
# 3331   N 4°57' 0'' / E 114°57' 0''
# 3334       ic zapekan6000 🎗 cbyf
# 3335                           hell
# 3337
# 3340                    St Louis, MO
# 3342                             NaN
# 3346                             NaN
# 3347       STR Real Estate Investing

# %%
# Here, all of the tweets in the sample contain 'matcha' and not 'macha'
df[df['Tweet'].str.contains('matcha')].sample(10)
# Out:
#                      Created at             User  \
# 1052  2022-10-06 20:35:55+00:00        manniests
# 1391  2022-10-05 15:46:22+00:00    harrysstargrl
# 512   2022-10-02 11:41:14+00:00    nurirdnaizzti
# 1617  2022-10-04 13:48:05+00:00          iEatOat
# 2741  2022-10-05 22:38:32+00:00      VacationAir
# 1730  2022-10-03 22:40:37+00:00     wrongadeline
# 1722  2022-10-04 00:27:32+00:00      halal_bitch
# 177   2022-10-06 20:10:16+00:00         taurmoon
# 2771  2022-10-05 19:42:46+00:00  tonichildsofmem
# 3046  2022-10-04 01:17:41+00:00       08GENESIS_
#
#                                                                                                                                                   Tweet  \
# 1052                                                              it was my mom and siblings.., even though my mom bought me my venti iced matcha latte
# 1391                                                       @curlieshoney2 iced matcha latte w two pumps chai and vanilla sweet cream cold foam PLEASEEE
# 512   @bagsdariclairo but after tambah pun sumpah rase die still ish taktahu cane nk explain😩 for matcha lover, i would n… https://t.co/z07AQwrINY
# 1617                                                                                                     i am just a girl Please give me a matcha latte
# 2741     @NyxTheNeko Hmm. It probably depends. Starbucks would be an iced matcha latte with no ice. Happy Lemon would be a s… https://t.co/JEgGIK6kaN
# 1730     they should do a matcha version of weed. just take the whole plant and grind it down into a powder. i don't do weed… https://t.co/mIYlI1lEBy
# 1722                                                                                            @marinaxdove i love an iced soy matcha latte w/ vanilla
# 177                                                 cant drink matcha or coffee today bc i haven’t been able to sleep lately  https://t.co/BNX8nG8Mrc
# 2771     @theprettyplaya @ThegirlJT Definitely! Lol my go to lately has been an iced matcha tea latte with oatmilk add 2 pum… https://t.co/cvbC6DzYQk
# 3046                                                                                                 @whisp0o matcha green tea or black tea w soy milk!
#
#                 ID  Number of Retweets  Number of likes              Source  \
# 1052  1.578120e+18                   0                1  Twitter for iPhone
# 1391  1.577690e+18                   0                1  Twitter for iPhone
# 512   1.576540e+18                   0                0  Twitter for iPhone
# 1617  1.577290e+18                   5               15  Twitter for iPhone
# 2741  1.577790e+18                   0                0     Twitter Web App
# 1730  1.577070e+18                   0                0     Twitter Web App
# 1722  1.577090e+18                   0                0     Twitter Web App
# 177   1.578120e+18                   0                0  Twitter for iPhone
# 2771  1.577750e+18                   0                1  Twitter for iPhone
# 3046  1.577110e+18                   0                1  Twitter for iPhone
#
#                               Location
# 1052        black/samoan 19 (she/they)
# 1391                              20!!
# 512                 Shah Alam,Selangor
# 1617  ed recov \nedtwt dni\nshe her 16
# 2741                        Texas, USA
# 1730               atop a small flower
# 1722                            Philly
# 177                       kyungsoodise
# 2771                     South Memphis
# 3046                               NaN

# %%
# Find duplicated rows that have the same value in 'Tweet' column
df[df.duplicated(subset='Tweet')].head()
# Out:
#                     Created at             User  \
# 559  2022-10-09 15:54:44+00:00     dellianarose
# 569  2022-10-09 14:57:00+00:00  atasteofmadness
# 576  2022-10-09 14:21:21+00:00        ogidigest
# 588  2022-10-09 13:28:29+00:00     fukuroumochi
# 605  2022-10-09 10:16:36+00:00        piirtelen
#
#                                                                                                                                                               Tweet  \
# 559          Height: 5’3”\nAge: 29\nShoe Size: 8 or 9 (depending on the shoe) \nZodiac Sign: Sagittarius \nTattoos: 1 \nPiercings: 2… https://t.co/VA5nQx4NuK
# 569                  Easy Vanilla Matcha Chai Latte recipe. This healthy warm comforting drink idea is vegan and gluten free, perfect on… https://t.co/CUpNVNNdbh
# 576                                                                                            did you drink your oatly matcha latte today? https://t.co/Hb9bu8SWGX
# 588  5 tags, 5 faves!\n\nfood: SUKIYAKI!! 🍲 \ndrink: matcha latte 🍵\ncolor: Seijoh color 💚🤍 (is it mint green or turquoise b… https://t.co/tChOZzN5VX
# 605        thank you for the tag cheese💕\n\n5 tags &amp; faves\nFood - i don't have a #1 but would currently love some bbq after fore… https://t.co/b2L9KzfdAO
#
#                ID  Number of Retweets  Number of likes               Source  \
# 559  1.579140e+18                   0                0   Twitter for iPhone
# 569  1.579120e+18                   1                0      Twitter Web App
# 576  1.579110e+18                   0                0      Twitter Web App
# 588  1.579100e+18                   0                2      Twitter Web App
# 605  1.579050e+18                   0                2  Twitter for Android
#
#                  Location
# 559       Ottawa, Ontario
# 569           Chicago, IL
# 576                   NaN
# 588       she/her • 25+
# 605  🇫🇮 | they/them

# %%
# duplicates count
df.duplicated(subset='Tweet').sum()
# Out:
# 413

# %%
# remving rows that have "RT" in the begining of the tweet
df = df[df["Tweet"].str.contains("RT") == False]

# %%
# check if rows that "RT" in the begining of the tweet have been removed
df[df["Tweet"].str.contains("RT")]
# empty dataframe means no tweet exists with such keyword
# Out:
# Empty DataFrame
# Columns: [Created at, User, Tweet, ID, Number of Retweets, Number of likes, Source, Location]
# Index: []

# %%
# check if duplicates were removed
df.duplicated(subset='Tweet').sum()
# Out:
# 411

# %%
# Display duplicated rows
duplicateRowsDF = df[df.duplicated(subset='Tweet')]
duplicateRowsDF.head(4)
# Out:
#                     Created at             User  \
# 559  2022-10-09 15:54:44+00:00     dellianarose
# 569  2022-10-09 14:57:00+00:00  atasteofmadness
# 576  2022-10-09 14:21:21+00:00        ogidigest
# 588  2022-10-09 13:28:29+00:00     fukuroumochi
#
#                                                                                                                                                               Tweet  \
# 559          Height: 5’3”\nAge: 29\nShoe Size: 8 or 9 (depending on the shoe) \nZodiac Sign: Sagittarius \nTattoos: 1 \nPiercings: 2… https://t.co/VA5nQx4NuK
# 569                  Easy Vanilla Matcha Chai Latte recipe. This healthy warm comforting drink idea is vegan and gluten free, perfect on… https://t.co/CUpNVNNdbh
# 576                                                                                            did you drink your oatly matcha latte today? https://t.co/Hb9bu8SWGX
# 588  5 tags, 5 faves!\n\nfood: SUKIYAKI!! 🍲 \ndrink: matcha latte 🍵\ncolor: Seijoh color 💚🤍 (is it mint green or turquoise b… https://t.co/tChOZzN5VX
#
#                ID  Number of Retweets  Number of likes              Source  \
# 559  1.579140e+18                   0                0  Twitter for iPhone
# 569  1.579120e+18                   1                0     Twitter Web App
# 576  1.579110e+18                   0                0     Twitter Web App
# 588  1.579100e+18                   0                2     Twitter Web App
#
#             Location
# 559  Ottawa, Ontario
# 569      Chicago, IL
# 576              NaN
# 588  she/her • 25+

# %%
# remove duplicates
df.drop_duplicates(subset='Tweet', inplace=True)

# %%
# check if duplicates were removed
df.duplicated(subset='Tweet').sum()
# Out:
# 0

# %%
# check total number of rows in df
df.shape
# Out:
# (2929, 8)

# %%
#Display tweets contain hyperlinks
df2[df2['Tweet'].str.contains('http\S')].count()
# Out:
# Created at            1680
# User                  1680
# Tweet                 1680
# ID                    1680
# Number of Retweets    1680
# Number of likes       1680
# Source                1680
# Location              1215
# dtype: int64

# %%
#Which .head(5) brings the 1st five rows tweets contain hyperlinks
#As shouwn; it brings rows contain Hyperlinks before manipulating 
df2[df2['Tweet'].str.contains('http\S')].head(5)
# Out:
#                   Created at             User  \
# 1  2022-10-09 15:54:44+00:00     dellianarose
# 3  2022-10-09 14:57:00+00:00  atasteofmadness
# 4  2022-10-09 14:21:21+00:00        ogidigest
# 5  2022-10-09 13:55:48+00:00      maryam_a201
# 6  2022-10-09 13:28:29+00:00     fukuroumochi
#
#                                                                                                                                                             Tweet  \
# 1          Height: 5’3”\nAge: 29\nShoe Size: 8 or 9 (depending on the shoe) \nZodiac Sign: Sagittarius \nTattoos: 1 \nPiercings: 2… https://t.co/VA5nQx4NuK
# 3                  Easy Vanilla Matcha Chai Latte recipe. This healthy warm comforting drink idea is vegan and gluten free, perfect on… https://t.co/CUpNVNNdbh
# 4                                                                                            did you drink your oatly matcha latte today? https://t.co/Hb9bu8SWGX
# 5                                                                                                  Id rather drink beer than drink matcha https://t.co/HiOMjtcJBG
# 6  5 tags, 5 faves!\n\nfood: SUKIYAKI!! 🍲 \ndrink: matcha latte 🍵\ncolor: Seijoh color 💚🤍 (is it mint green or turquoise b… https://t.co/tChOZzN5VX
#
#              ID  Number of Retweets  Number of likes              Source  \
# 1  1.579140e+18                   0                0  Twitter for iPhone
# 3  1.579120e+18                   1                0     Twitter Web App
# 4  1.579110e+18                   0                0     Twitter Web App
# 5  1.579110e+18                   0                0  Twitter for iPhone
# 6  1.579100e+18                   0                2     Twitter Web App
#
#           Location
# 1  Ottawa, Ontario
# 3      Chicago, IL
# 4              NaN
# 5    Rochester, NY
# 6  she/her • 25+

# %%
#This function removes hyperlinks from the tweets
def remove_URL(tweet):
    """Remove URLs from a sample string"""
    return re.sub(r"http\S+", "", tweet)

#Apply remove_URL method
df['Tweet'] = df['Tweet'].apply(remove_URL)

# %%
#To make sure 'Tweet' Column doesn't contain hyperlinks [I]
df[df['Tweet'].str.contains('http\S')].count()
# Out:
# Created at            0
# User                  0
# Tweet                 0
# ID                    0
# Number of Retweets    0
# Number of likes       0
# Source                0
# Location              0
# dtype: int64

# %%
#To make sure 'Tweet' Column doesn't contain hyperlinks [II]
#Which .head(5) brings the 1st five rows tweets contain hyperlinks
#As shouwn; it doesn't bring any row
df[df['Tweet'].str.contains('http\S')].head(5)
# Out:
# Empty DataFrame
# Columns: [Created at, User, Tweet, ID, Number of Retweets, Number of likes, Source, Location]
# Index: []

# %%
#To make sure 'Tweet' Column doesn't contain punctuations (comma as an example)
df[df['Tweet'].str.contains(',')].count()
# Out:
# Created at            747
# User                  747
# Tweet                 747
# ID                    747
# Number of Retweets    747
# Number of likes       747
# Source                747
# Location              524
# dtype: int64

# %%
df[df['Tweet'].str.contains(',')].head(5)
# Out:
#                    Created at             User  \
# 0   2022-10-09 15:56:27+00:00  SPStavrosAuthor
# 3   2022-10-09 14:57:00+00:00  atasteofmadness
# 6   2022-10-09 13:28:29+00:00     fukuroumochi
# 18  2022-10-09 07:36:31+00:00         ChronHib
# 25  2022-10-09 03:32:27+00:00         Helix_VA
#
#                                                                                                                                        Tweet  \
# 0                         @LynnDiavol I try to drink matcha over coffee, because it helps with anxiety problems instead of making them worse
# 3                    Easy Vanilla Matcha Chai Latte recipe. This healthy warm comforting drink idea is vegan and gluten free, perfect on…
# 6    5 tags, 5 faves!\n\nfood: SUKIYAKI!! 🍲 \ndrink: matcha latte 🍵\ncolor: Seijoh color 💚🤍 (is it mint green or turquoise b…
# 18                  @BigBisonHead @MarieTheuerkauf @NiksTeas And of course foamy matcha.\nUnfortunately, I can hardly ever drink tea aft…
# 25  Thanks Althea for the tag!\n\nHeight: 5'9, 175cm\nZodiac: Gemini♊️♊️\nTattoos: None (for now)\nColor: Black/Purple💜\nDrin…
#
#               ID  Number of Retweets  Number of likes               Source  \
# 0   1.579140e+18                   0                0  Twitter for Android
# 3   1.579120e+18                   1                0      Twitter Web App
# 6   1.579100e+18                   0                2      Twitter Web App
# 18  1.579010e+18                   0                2      Twitter Web App
# 25  1.578950e+18                   0                3      Twitter Web App
#
#                Location
# 0                Canada
# 3           Chicago, IL
# 6       she/her • 25+
# 18  Maynooth University
# 25     outer space 🌌

# %%
#This function removes punctuations from the tweets

def remove_punctuations(tweets):
    translator=str.maketrans('','',string.punctuation)
    newTweets=tweets.translate(translator)
    newTweets=''.join(c for c in newTweets.split())
    return newTweets

#Apply remove_punctuations method
df['Tweet'] = df['Tweet'].apply(remove_punctuations)

# %%
#To make sure 'Tweet' Column doesn't contain punctuations (comma as an example)
df[df['Tweet'].str.contains(',')].count()
# Out:
# Created at            0
# User                  0
# Tweet                 0
# ID                    0
# Number of Retweets    0
# Number of likes       0
# Source                0
# Location              0
# dtype: int64

# %%
df[df['Tweet'].str.contains(',')].head(5)
# Out:
# Empty DataFrame
# Columns: [Created at, User, Tweet, ID, Number of Retweets, Number of likes, Source, Location]
# Index: []

# %%
#This function removes # ,@ and new lines from tweets

def remove_hashtags(tweet):
    #Replace #word with word
    tweet = re.sub(r'#([^\s]+)', r'\1', tweet)
    tweet = re.sub(r'\n','. ', tweet)
    
    #Replace @username with empty string
    tweet = re.sub('@[^\s]+', ' ', tweet)
    
    #Replace new lines with white space
    tweet = tweet.replace('\n',' ')
    tweet = tweet.replace('\t',' ')
    tweet = tweet.replace('_',' ')
    tweet = tweet.replace('\r',' ')
    
    return tweet
