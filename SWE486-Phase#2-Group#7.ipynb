# %%
#Libraries

import pandas as pd
import re

# Display the tweet fully using:
pd.set_option('display.max_colwidth', None)
pd.set_option('max_colwidth', None)

# %%
df = pd.read_csv('Matcha#Dataset.csv')

# %%
# to return columns' names of the dataset
df.columns
# Out:
# Index(['Created at', 'User', 'Tweet', 'ID', 'Number of Retweets',
#        'Number of likes', 'Source', 'Location'],
#       dtype='object')

# %%
# to return each column with the corresponding non-null values count and its data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3348 entries, 0 to 3347
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Created at          3348 non-null   object
#  1   User                3348 non-null   object
#  2   Tweet               3348 non-null   object
#  3   ID                  3348 non-null   float64
#  4   Number of Retweets  3348 non-null   int64
#  5   Number of likes     3348 non-null   int64
#  6   Source              3348 non-null   object
#  7   Location            2390 non-null   object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 209.4+ KB

# %%
# to return the count of non-null values in each column
df.count()
# Out:
# Created at            3348
# User                  3348
# Tweet                 3348
# ID                    3348
# Number of Retweets    3348
# Number of likes       3348
# Source                3348
# Location              2390
# dtype: int64

# %%
# to return the total number of rows
len(df)
# Out:
# 3348

# %%
# to return statistical calculations
df.describe()
# Out:
#                  ID  Number of Retweets  Number of likes
# count  3.348000e+03         3348.000000      3348.000000
# mean   1.577715e+18            0.250000         3.643967
# std    7.962897e+14            2.803906        40.340408
# min    1.576250e+18            0.000000         0.000000
# 25%    1.577080e+18            0.000000         0.000000
# 50%    1.577730e+18            0.000000         1.000000
# 75%    1.578390e+18            0.000000         2.000000
# max    1.579140e+18           77.000000      2132.000000

# %%
df.head()
# Out:
#                   Created at             User  \
# 0  2022-10-09 15:56:27+00:00  SPStavrosAuthor
# 1  2022-10-09 15:54:44+00:00     dellianarose
# 2  2022-10-09 15:36:25+00:00        DeeReads_
# 3  2022-10-09 14:57:00+00:00  atasteofmadness
# 4  2022-10-09 14:21:21+00:00        ogidigest
#
#                                                                                                                                                     Tweet  \
# 0                                      @LynnDiavol I try to drink matcha over coffee, because it helps with anxiety problems instead of making them worse
# 1  Height: 5’3”\nAge: 29\nShoe Size: 8 or 9 (depending on the shoe) \nZodiac Sign: Sagittarius \nTattoos: 1 \nPiercings: 2… https://t.co/VA5nQx4NuK
# 2                                                                                                                                    drink matcha and sin
# 3          Easy Vanilla Matcha Chai Latte recipe. This healthy warm comforting drink idea is vegan and gluten free, perfect on… https://t.co/CUpNVNNdbh
# 4                                                                                    did you drink your oatly matcha latte today? https://t.co/Hb9bu8SWGX
#
#              ID  Number of Retweets  Number of likes               Source  \
# 0  1.579140e+18                   0                0  Twitter for Android
# 1  1.579140e+18                   0                0   Twitter for iPhone
# 2  1.579130e+18                   0                1      Twitter Web App
# 3  1.579120e+18                   1                0      Twitter Web App
# 4  1.579110e+18                   0                0      Twitter Web App
#
#           Location
# 0           Canada
# 1  Ottawa, Ontario
# 2              NaN
# 3      Chicago, IL
# 4              NaN

# %%
df.shape
# Out:
# (3348, 8)

# %% [markdown]
# Data Issues:

# %%
# NORMALIZATION PROBLEM

# It's been noticed that some Twitter users use 'Matcha' and sometimes 'Macha' while referring to the same drink.
# Therefore, it will be normalized to 'Matcha' in all tweets.

#This method takes the tweet as the parameter, normalizes the drink's spelling, then returns it.
def normalize(tweet):
    text = re.sub("macha","matcha", tweet)
    return tweet

# %%
df['Tweet'] = df['Tweet'].apply(normalize)

# %%
#Return a sample of the dataset
df.sample(5)
# Out:
#                      Created at             User  \
# 3012  2022-10-04 05:46:06+00:00          dsemumi
# 1761  2022-10-03 18:24:03+00:00  lalisarubyjanes
# 1682  2022-10-04 06:17:41+00:00         sngo1982
# 467   2022-10-03 07:09:59+00:00       yanahluixz
# 617   2022-10-09 07:49:17+00:00          febsal_
#
#                                                                                                                                                    Tweet  \
# 3012       @tabimori iced matcha tea latte w/ oatmilk and the brown sugar espresso the other person mentioned are undefeated.… https://t.co/r0vI1IaIfh
# 1761                                             @lrdhive iced chai latte with a shot of espresso or iced matcha latte with oat milk and 2 pumps of chai
# 1682  I so miss @KurtGeiger shoes in #melbourne &amp; had an iced #matcha #greentea latte in the city, just doing some lite w… https://t.co/1jfJlWGlFz
# 467                           no bc why am i even craving ung matcha drink sa sb???! i have never even ordered it before 🤡 tanginang takaw tingin toh
# 617       trying to come to terms w the fact that i will never love another matcha drink than the last matcha latte recipe fr… https://t.co/n1UbWgcMeO
#
#                 ID  Number of Retweets  Number of likes               Source  \
# 3012  1.577170e+18                   0                1   Twitter for iPhone
# 1761  1.577000e+18                   0                1   Twitter for iPhone
# 1682  1.577180e+18                   0                0   Twitter for iPhone
# 467   1.576830e+18                   0                2   Twitter for iPhone
# 617   1.579020e+18                   0                1  Twitter for Android
#
#        Location
# 3012    seattle
# 1761  he/him 21
# 1682        NaN
# 467       shaik
# 617         NaN

# %%
# To check if 'macha' has been replaced with 'matcha', an attempt to return any tweet that contains the word 'macha' is made
# However, the dataframe returned is empty, which means there aren't any tweets with the word 'macha', and our normalization
# is successful!

df[df['Tweet'].str.contains('macha')]
# Out:
# Empty DataFrame
# Columns: [Created at, User, Tweet, ID, Number of Retweets, Number of likes, Source, Location]
# Index: []

# %%
# Here, all of the tweets in the sample contain 'matcha' and not 'macha'
df[df['Tweet'].str.contains('matcha')].sample(10)
# Out:
#                      Created at             User  \
# 248   2022-10-05 21:55:40+00:00    DrakesCupcake
# 1732  2022-10-03 22:03:24+00:00      ___kristieK
# 428   2022-10-03 19:45:00+00:00   Obscure_Occult
# 2327  2022-10-09 03:36:49+00:00  wahinertraveler
# 2096  2022-10-01 17:40:15+00:00      NicolePajer
# 848   2022-10-07 22:20:49+00:00   brittneytran01
# 2910  2022-10-04 21:12:53+00:00       f1girlelle
# 876   2022-10-07 18:59:09+00:00   immoniquerenee
# 187   2022-10-06 17:37:27+00:00       hehe_xd333
# 1157  2022-10-06 12:25:42+00:00        Yukikoona
#
#                                                                                                                                                      Tweet  \
# 248                                                                         @ThegirlJT Venti pink drink \nVanilla cold foam \nAnd a scoop of matcha powder
# 1732                                                                                                                            I want a matcha latte 🙃
# 428                                              @smuttysunflower Not yet but starbucks has a hocus pocus themed drink its pretty good if you like matcha.
# 2327  @LynnDiavol Darjeeling, Earl Grey if accompanied by a salty snack, Roiboos🌍, @ times ginger tea, + matcha💚 in all f… https://t.co/bdywHqZuib
# 2096        Had a matcha tea latte at Starbucks yesterday (haven't had one in so long b/c of dairy but they now have coconut mi… https://t.co/DLKo6h91pH
# 848           Let my coworker who’s a coffee drinker try my matcha latte from Starbucks for the first time and SHE LOVED IT. Matcha girlies 🫶🏼💚
# 2910  five tags, five favs\n\nFood: quesadillas, tacos\nDrink: matcha tea \nColor: baby blue, green \nSeason: winter \nShow: Th… https://t.co/XXX7ygizHf
# 876                                                          Woke up this morning and decided to take a walk instead of driving to get my matcha latte …
# 187                                                                                                                 @swordgirlfriend drink matcha or yerba
# 1157                                                            I made matcha latte and it taste pretty good, i was surprised lmao https://t.co/4zZzoFj5Dg
#
#                 ID  Number of Retweets  Number of likes               Source  \
# 248   1.577780e+18                   0                0   Twitter for iPhone
# 1732  1.577060e+18                   0                0   Twitter for iPhone
# 428   1.577020e+18                   0                0  Twitter for Android
# 2327  1.578950e+18                   0                2      Twitter Web App
# 2096  1.576270e+18                   0                8      Twitter Web App
# 848   1.578510e+18                   0                2   Twitter for iPhone
# 2910  1.577410e+18                   0                5   Twitter for iPhone
# 876   1.578460e+18                   0                3   Twitter for iPhone
# 187   1.578080e+18                   0                0      Twitter Web App
# 1157  1.578000e+18                   1                2  Twitter for Android
#
#                             Location
# 248                   Palm Beach, FL
# 1732                             NaN
# 428                              NaN
# 2327                             NaN
# 2096                             NaN
# 848                              NaN
# 2910  CL 16|CS5 5|MV 1|SP 11|DR 3|LN
# 876                Hermosa Beach, CA
# 187                           Europe
# 1157                   Kevin's boobs
